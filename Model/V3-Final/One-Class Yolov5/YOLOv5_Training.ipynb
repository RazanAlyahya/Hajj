# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Video/YOLOv5.zip
# Out:
# Archive:  /content/drive/MyDrive/Video/YOLOv5.zip
#    creating: YOLOv5/.idea/
#  extracting: YOLOv5/.idea/.gitignore
#    creating: YOLOv5/.idea/inspectionProfiles/
#   inflating: YOLOv5/.idea/inspectionProfiles/profiles_settings.xml
#   inflating: YOLOv5/.idea/misc.xml
#   inflating: YOLOv5/.idea/modules.xml
#   inflating: YOLOv5/.idea/vcs.xml
#   inflating: YOLOv5/.idea/workspace.xml
#   inflating: YOLOv5/.idea/YOLOv5.iml
#    creating: YOLOv5/yolov5/
#   inflating: YOLOv5/yolov5/.dockerignore
#    creating: YOLOv5/yolov5/.git/
#   inflating: YOLOv5/yolov5/.git/config
#   inflating: YOLOv5/yolov5/.git/description
#   inflating: YOLOv5/yolov5/.git/FETCH_HEAD
#  extracting: YOLOv5/yolov5/.git/HEAD
#    creating: YOLOv5/yolov5/.git/hooks/
#   inflating: YOLOv5/yolov5/.git/hooks/applypatch-msg.sample
#   inflating: YOLOv5/yolov5/.git/hooks/commit-msg.sample
#   inflating: YOLOv5/yolov5/.git/hooks/fsmonitor-watchman.sample
#   inflating: YOLOv5/yolov5/.git/hooks/post-update.sample
# ...

# %%
# !unzip /content/drive/MyDrive/Video/YOLO_Data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: YOLO_Data/trainData/labels/12_470.txt
#   inflating: YOLO_Data/trainData/labels/12_464.txt
#   inflating: YOLO_Data/trainData/labels/9_489.txt
#   inflating: YOLO_Data/trainData/labels/3_159.txt
#   inflating: YOLO_Data/trainData/labels/12_302.txt
#   inflating: YOLO_Data/trainData/labels/2_362.txt
#   inflating: YOLO_Data/trainData/labels/3_171.txt
#   inflating: YOLO_Data/trainData/labels/5_685.txt
#   inflating: YOLO_Data/trainData/labels/7_233.txt
#   inflating: YOLO_Data/trainData/labels/3_617.txt
#   inflating: YOLO_Data/trainData/labels/2_404.txt
#   inflating: YOLO_Data/trainData/labels/7_227.txt
#   inflating: YOLO_Data/trainData/labels/3_603.txt
#   inflating: YOLO_Data/trainData/labels/2_410.txt
#   inflating: YOLO_Data/trainData/labels/12_458.txt
#   inflating: YOLO_Data/trainData/labels/2_376.txt
#   inflating: YOLO_Data/trainData/labels/3_165.txt
#   inflating: YOLO_Data/trainData/labels/5_691.txt
# ...

# %%
# !cp -r /content/YOLO_Data /content/YOLOv5/yolov5

# %%
cd YOLOv5
# Out:
# /content/YOLOv5

# %%
cd yolov5
# Out:
# /content/YOLOv5/yolov5

# %%
pwd
# Out:
# '/content/YOLOv5/yolov5'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.4/616.4 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# !python train.py --data data.yaml --cfg yolov5-mobilenet.yaml --batch-size -1 --epochs 300 --cache
# Out:
# train: weights=yolov5s.pt, cfg=yolov5-mobilenet.yaml, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (1/1), 761 bytes | 761.00 KiB/s, done.
# From https://github.com/ultralytics/yolov5
#    8c45e51..9e97ac3  master     -> origin/master
# ...

# %%
# !zip -r /content/drive/MyDrive/Video/300epochs.zip /content/YOLOv5/yolov5/runs/train/exp11
# Out:
#   adding: content/YOLOv5/yolov5/runs/train/exp11/ (stored 0%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/val_batch1_pred.jpg (deflated 5%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/train_batch0.jpg (deflated 1%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/val_batch0_pred.jpg (deflated 6%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/results.png (deflated 9%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/train_batch2.jpg (deflated 2%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/R_curve.png (deflated 19%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/PR_curve.png (deflated 19%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/P_curve.png (deflated 22%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/confusion_matrix.png (deflated 38%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/val_batch2_pred.jpg (deflated 5%)
#   adding: content/YOLOv5/yolov5/runs/train/exp11/events.out.tfevents.1694674046.4738b2f3593f.5686.0 (deflated 47%)
# ...
